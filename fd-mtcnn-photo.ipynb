# %%
# face detection with mtcnn on a photograph
from matplotlib import pyplot
from matplotlib.patches import Rectangle
from mtcnn.mtcnn import MTCNN

# %%
# draw an image with detected objects
def draw_image_with_boxes(filename, result_list):
    # load the image
    data = pyplot.imread(filename)
    # plot the image
    pyplot.imshow(data)
    # get the context for drawing boxes
    ax = pyplot.gca()
    # plot each box
    for result in result_list:
        # get coordinates
        x, y, width, height = result['box']
        # create the shape
        rect = Rectangle((x, y), width, height, fill=False, color='red')
        # draw the box
        ax.add_patch(rect)
        
    # show the plot
    pyplot.show()

# %%
#filename = './myimages/dog.jpeg'
filename = './test/test1.jpg'
# load image from file
pixels = pyplot.imread(filename)
# create the detector, using default weights
detector = MTCNN()
# detect faces in the image
faces = detector.detect_faces(pixels)
# display faces on the original image
draw_image_with_boxes(filename, faces)
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0115 09:40:03.421711 4592719296 deprecation_wrapper.py:119] From /anaconda3/lib/python3.7/site-packages/mtcnn/mtcnn.py:187: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# W0115 09:40:03.442652 4592719296 deprecation_wrapper.py:119] From /anaconda3/lib/python3.7/site-packages/mtcnn/mtcnn.py:193: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# W0115 09:40:03.473946 4592719296 deprecation_wrapper.py:119] From /anaconda3/lib/python3.7/site-packages/mtcnn/network.py:43: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# W0115 09:40:03.476223 4592719296 deprecation_wrapper.py:119] From /anaconda3/lib/python3.7/site-packages/mtcnn/layer_factory.py:88: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# ...

# %%
filename = './test/110.jpg'
# load image from file
pixels = pyplot.imread(filename)
# create the detector, using default weights
detector = MTCNN()
# detect faces in the image
faces = detector.detect_faces(pixels)
# display faces on the original image
draw_image_with_boxes(filename, faces)

# %%
filename = './myimages/7.jpg'
# load image from file
pixels = pyplot.imread(filename)
# create the detector, using default weights
detector = MTCNN()
# detect faces in the image
faces = detector.detect_faces(pixels)
# display faces on the original image
draw_image_with_boxes(filename, faces)

# %%
filename = './myimages/5.jpg'
# load image from file
pixels = pyplot.imread(filename)
# create the detector, using default weights
detector = MTCNN()
# detect faces in the image
faces = detector.detect_faces(pixels)
# display faces on the original image
draw_image_with_boxes(filename, faces)

# %%
filename = './test/210.jpg'
# load image from file
pixels = pyplot.imread(filename)
# create the detector, using default weights
detector = MTCNN()
# detect faces in the image
faces = detector.detect_faces(pixels)
# display faces on the original image
draw_image_with_boxes(filename, faces)

# %%
filename = './test/011.jpg'
# load image from file
pixels = pyplot.imread(filename)
# create the detector, using default weights
detector = MTCNN()
# detect faces in the image
faces = detector.detect_faces(pixels)
# display faces on the original image
draw_image_with_boxes(filename, faces)

# %% [markdown]
# # Face Extraction

# %%
# create the detector, using default weights
detector = MTCNN()

# %%
from PIL import Image
from numpy import asarray
def extract_face(filename, required_size=(224, 224)):
    # load image from file
    pixels = pyplot.imread(filename)
    # create the detector, using default weights
    # detect faces in the image
    results = detector.detect_faces(pixels)
    # extract the bounding box from the first face
    x1, y1, width, height = results[0]['box']
    x2, y2 = x1 + width, y1 + height
    # extract the face
    face = pixels[y1:y2, x1:x2]
    # resize pixels to the model size
    image = Image.fromarray(face)
    image = image.resize(required_size)
    face_array = asarray(image)
    return face_array

# %%
filename = './myimages/joli13.jpeg'
pyplot.imshow(extract_face(filename))
pyplot.show()

# %%
import cv2
im = extract_face(filename)
im.shape
# Out:
# (224, 224, 3)

# %%
pyplot.savefig('/Users/amin.oroji/Desktop/joli_img.png')

# %%
cv2.imwrite('/Users/amin.oroji/Desktop/joli_img.png',im)
# Out:
# True

# %%
img = pyplot.imread('/Users/amin.oroji/Desktop/joli_img.png')
pyplot.imshow(im)
pyplot.show()

# %%
dim = (224,224)

# %%
img = pyplot.imread('/Users/amin.oroji/Documents/Einnity/PAPERS/Paper2/face-detection2.png')

im = cv2.resize(img, dim, interpolation = cv2.INTER_AREA)

im.shape

pyplot.imshow(im)
pyplot.show()

# %%
im2 = pyplot.imread('/Users/amin.oroji/Documents/Einnity/PAPERS/Paper2/joli13.jpeg')
im = cv2.resize(im2, dim, interpolation = cv2.INTER_AREA)

im.shape

pyplot.imshow(im)
pyplot.show()
